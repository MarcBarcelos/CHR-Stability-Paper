# %%
import pandas as pd

# %%
df= pd.read_csv("/Users/au728638/Library/CloudStorage/OneDrive-Aarhusuniversitet/Desktop/3. PhD Project/3. Code/chr_stability_paper/outputs/results/outputs/AO3metrics_full.csv")

# %%
df.columns
# Out:
# Index(['id', 'title', 'author', 'fandom', 'published', 'rating', 'words',
#        'chapters', 'fandom_label', 'source',
#        ...
#        'parenthesis_rate', 'quotation_rate', 'ellipsis_rate',
#        'subordination_ratio', 'coordination_ratio', 'clauses_per_sentence',
#        'parse_tree_depth_mean', 'parse_tree_depth_std',
#        'mean_dependents_per_head', 'prop_complex_sentences'],
#       dtype='str', length=135)

# %%
print(list(df.columns))
# Out:
# ['id', 'title', 'author', 'fandom', 'published', 'rating', 'words', 'chapters', 'fandom_label', 'source', 'mattr', 'H_unigram_win_mean_nats', 'H_unigram_win_std_nats', 'PPL_unigram_win_mean', 'H_3gram_self_nats', 'PPL_3gram_self_nats', 'dependency_distance_mean', 'dependency_distance_std', 'prop_adjacent_dependency_relation_mean', 'prop_adjacent_dependency_relation_std', 'first_order_coherence_x', 'second_order_coherence_x', 'token_length_mean', 'token_length_median', 'token_length_std', 'sentence_length_mean', 'sentence_length_median', 'sentence_length_std', 'syllables_per_token_mean', 'syllables_per_token_median', 'syllables_per_token_std', 'n_tokens', 'n_unique_tokens', 'proportion_unique_tokens', 'n_characters', 'n_sentences', 'pos_prop_ADJ', 'pos_prop_ADP', 'pos_prop_ADV', 'pos_prop_AUX', 'pos_prop_CCONJ', 'pos_prop_DET', 'pos_prop_INTJ', 'pos_prop_NOUN', 'pos_prop_NUM', 'pos_prop_PART', 'pos_prop_PRON', 'pos_prop_PROPN', 'pos_prop_PUNCT', 'pos_prop_SCONJ', 'pos_prop_SYM', 'pos_
# ...
