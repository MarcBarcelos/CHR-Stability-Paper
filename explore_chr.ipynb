# %% [markdown]
# # Descriptive Bits and Bobs for the Paper

# %%
import pandas as pd

# %%
df= pd.read_csv("/Users/au728638/Library/CloudStorage/OneDrive-Aarhusuniversitet/Desktop/3. PhD Project/3. Code/chr_stability_paper/data/AO3metrics_full.csv")

# %%
df.columns[:15]
# Out:
# Index(['id', 'title', 'author', 'fandom', 'published', 'rating', 'words',
#        'chapters', 'fandom_label', 'source', 'mattr',
#        'H_unigram_win_mean_nats', 'H_unigram_win_std_nats',
#        'PPL_unigram_win_mean', 'H_3gram_self_nats'],
#       dtype='str')

# %% [markdown]
# ### Checking unique number of fandoms in the random subset of the data

# %%
len(df[df.fandom_label == "random"].fandom.unique())
# Out:
# 1710
