# %%
import pandas as pd

# %%
df= pd.read_csv("/Users/au728638/Library/CloudStorage/OneDrive-Aarhusuniversitet/Desktop/3. PhD Project/5. Data/mia_data/human_texts_2023_2025.csv")

# %%
df.columns
# Out:
# Index(['work_id', 'title', 'author', 'fandom', 'published', 'rating', 'words',
#        'chapters', 'text', 'fandom_label'],
#       dtype='str')

# %%
df["text"].head
# Out:
# <bound method NDFrame.head of 0       Work Text: Ke Li Si Di Nuo Gen Wo Shuo ,Ta Cen...
# 1       Work Text: They say if you imagine your lover'...
# 2       Work Text: "You should eat something, hun."Sil...
# 3       Work Text:  baby, we should have left our love...
# 4       Work Text: Ava meets Daisy on the day after sh...
#                               ...
# 3487    Work Text: " look what I got! "   He was in a ...
# 3488    Work Text: Vax didn't know how it had happened...
# 3489    Work Text:  Darcy peruses her reflection, fuss...
# 3490    Work Text: It wasn't normal.Seungkwan knew thi...
# 3491    Work Text: You lay awake at night, unable to s...
# Name: text, Length: 3492, dtype: str>
